# %% [markdown]
# # PyCity Schools Analysis
# -
#
# ---

# %%
# set up dependencies, import pandas and connect path
import pandas as pd
from pathlib import Path

# load the csv files from resources
school_data_to_load = Path("../Resources/schools_complete.csv")
student_data_to_load = Path("../Resources/students_complete.csv")

# read schoool_data_to_load for the school data 
# read student_data_to_load for student data
# store into pandas dataframes
school_data = pd.read_csv(school_data_to_load)
student_data = pd.read_csv(student_data_to_load)

# combine school data & student data aka merge  
school_data_complete = pd.merge(student_data, school_data, how="left", on=["school_name", "school_name"])
school_data_complete.head()
# Out:
#    Student ID       student_name gender grade        school_name  \
# 0           0       Paul Bradley      M   9th  Huang High School
# 1           1       Victor Smith      M  12th  Huang High School
# 2           2    Kevin Rodriguez      M  12th  Huang High School
# 3           3  Dr. Richard Scott      M  12th  Huang High School
# 4           4         Bonnie Ray      F   9th  Huang High School
#
#    reading_score  math_score  School ID      type  size   budget
# 0             66          79          0  District  2917  1910635
# 1             94          61          0  District  2917  1910635
# 2             90          60          0  District  2917  1910635
# 3             67          58          0  District  2917  1910635
# 4             97          84          0  District  2917  1910635

# %% [markdown]
# ## District Summary

# %%
# calculate the total number of unique schools using .unique(), it returns unique elements in the form of a sorted array
# use len to return the # of schools based on the school name
school_count = len(school_data_complete["school_name"].unique())

school_count
# Out:
# 15

# %%
# calculate the total number of students
# don't use student name b/c some students might have the same name
# again use .unique() & len
student_count = len(school_data_complete["Student ID"].unique())

student_count
# Out:
# 39170

# %%
# calculate total budget using .sum(), it adds up everything in a column
total_budget = school_data['budget'].sum()

total_budget
# Out:
# 24649428

# %%
# use .mean() to calculate the avg math score
avg_math_score = school_data_complete['math_score'].mean()

avg_math_score
# Out:
# 78.98537145774827

# %%
# again use .mean() to find avg reading score
average_reading_score = school_data_complete['reading_score'].mean()

average_reading_score
# Out:
# 81.87784018381414

# %%
# Use the following to calculate the percentage of students who passed math 
passing_math_count = school_data_complete[(school_data_complete["math_score"] >= 70)
                                            ].count()["student_name"]

passing_math_percentage = passing_math_count / float(student_count) * 100

passing_math_percentage
# Out:
# 74.9808526933878

# %%
# use what was given above to calculate the percentage of students who passed reading (math scores >= to 70)  
passing_reading_count = school_data_complete[(school_data_complete["reading_score"] >= 70)
                                                ].count()["student_name"]

passing_reading_percentage = passing_reading_count / float (student_count) * 100

passing_reading_percentage
# Out:
# 85.80546336482001

# %%
# Use the following to calculate the percentage of students that passed math and reading
passing_math_reading_count = school_data_complete[
    (school_data_complete["math_score"] >= 70) & (school_data_complete["reading_score"] >= 70)
].count()["student_name"]
overall_passing_rate = passing_math_reading_count /  float(student_count) * 100
overall_passing_rate
# Out:
# 65.17232575950983

# %%
# Create a high-level snapshot of the district's key metrics in a DataFrame
district_summary = pd.DataFrame({
                                'Total Schools':[school_count], 
                                'Total Students':[student_count],	
                                'Total Budget':[total_budget],	
                                'Average Math Score': [avg_math_score],
                                'Average Reading Score': [average_reading_score],	
                                '% Passing Math': [passing_math_percentage],
                                '% Passing Reading': [passing_reading_percentage],
                                '% Overall Passing': [overall_passing_rate]
                                 })

#  Formatting
district_summary["Total Students"] = district_summary["Total Students"].map("{:,}".format)
district_summary["Total Budget"] = district_summary["Total Budget"].map("${:,.2f}".format)

# Display the DataFrame
district_summary
# Out:
#    Total Schools Total Students    Total Budget  Average Math Score  \
# 0             15         39,170  $24,649,428.00           78.985371
#
#    Average Reading Score  % Passing Math  % Passing Reading  % Overall Passing
# 0               81.87784       74.980853          85.805463          65.172326

# %% [markdown]
# ## School Summary

# %%
# so i don't have to scroll all the way up again 
school_data_complete.head()
# Out:
#    Student ID       student_name gender grade        school_name  \
# 0           0       Paul Bradley      M   9th  Huang High School
# 1           1       Victor Smith      M  12th  Huang High School
# 2           2    Kevin Rodriguez      M  12th  Huang High School
# 3           3  Dr. Richard Scott      M  12th  Huang High School
# 4           4         Bonnie Ray      F   9th  Huang High School
#
#    reading_score  math_score  School ID      type  size   budget
# 0             66          79          0  District  2917  1910635
# 1             94          61          0  District  2917  1910635
# 2             90          60          0  District  2917  1910635
# 3             67          58          0  District  2917  1910635
# 4             97          84          0  District  2917  1910635

# %%
# Use the code provided to select all of the school types

# reset index !!! 
school_types = school_data.set_index(['school_name'])['type']

# naming it bc i kept getting an error saying that my series needed a name
school_types.name = 'school typess'

school_types
# Out:
# school_name
# Huang High School        District
# Figueroa High School     District
# Shelton High School       Charter
# Hernandez High School    District
# Griffin High School       Charter
# Wilson High School        Charter
# Cabrera High School       Charter
# Bailey High School       District
# Holden High School        Charter
# Pena High School          Charter
# Wright High School        Charter
# Rodriguez High School    District
# Johnson High School      District
# Ford High School         District
# Thomas High School        Charter
# Name: school typess, dtype: object

# %%
# Calculate the total student count per school

# use .value_count bc it will count up how nany there are
per_school_counts = school_data_complete[['school_name','student_name']].value_counts("school_name")
per_school_counts.name  = 'total student count'

per_school_counts
# Out:
# school_name
# Bailey High School       4976
# Johnson High School      4761
# Hernandez High School    4635
# Rodriguez High School    3999
# Figueroa High School     2949
# Huang High School        2917
# Ford High School         2739
# Wilson High School       2283
# Cabrera High School      1858
# Wright High School       1800
# Shelton High School      1761
# Thomas High School       1635
# Griffin High School      1468
# Pena High School          962
# Holden High School        427
# Name: total student count, dtype: int64

# %%
# Calculate the total school budget 
per_school_budget = school_data_complete.groupby(['school_name'])['budget'].mean()

per_school_budget
# Out:
# school_name
# Bailey High School       3124928.0
# Cabrera High School      1081356.0
# Figueroa High School     1884411.0
# Ford High School         1763916.0
# Griffin High School       917500.0
# Hernandez High School    3022020.0
# Holden High School        248087.0
# Huang High School        1910635.0
# Johnson High School      3094650.0
# Pena High School          585858.0
# Rodriguez High School    2547363.0
# Shelton High School      1056600.0
# Thomas High School       1043130.0
# Wilson High School       1319574.0
# Wright High School       1049400.0
# Name: budget, dtype: float64

# %%
# and per capita spending per school
per_school_capita = per_school_budget / per_school_counts
per_school_capita.name = 'capita'

per_school_capita
# Out:
# school_name
# Bailey High School       628.0
# Cabrera High School      582.0
# Figueroa High School     639.0
# Ford High School         644.0
# Griffin High School      625.0
# Hernandez High School    652.0
# Holden High School       581.0
# Huang High School        655.0
# Johnson High School      650.0
# Pena High School         609.0
# Rodriguez High School    637.0
# Shelton High School      600.0
# Thomas High School       638.0
# Wilson High School       578.0
# Wright High School       583.0
# Name: capita, dtype: float64

# %%
# use .mean() to calculate the average test scores per school

# math :
per_school_math = school_data_complete.groupby(['school_name'])['math_score'].mean()

per_school_math
# Out:
# school_name
# Bailey High School       77.048432
# Cabrera High School      83.061895
# Figueroa High School     76.711767
# Ford High School         77.102592
# Griffin High School      83.351499
# Hernandez High School    77.289752
# Holden High School       83.803279
# Huang High School        76.629414
# Johnson High School      77.072464
# Pena High School         83.839917
# Rodriguez High School    76.842711
# Shelton High School      83.359455
# Thomas High School       83.418349
# Wilson High School       83.274201
# Wright High School       83.682222
# Name: math_score, dtype: float64

# %%
# reading :
per_school_reading = school_data_complete.groupby(['school_name'])['reading_score'].mean()

per_school_reading
# Out:
# school_name
# Bailey High School       81.033963
# Cabrera High School      83.975780
# Figueroa High School     81.158020
# Ford High School         80.746258
# Griffin High School      83.816757
# Hernandez High School    80.934412
# Holden High School       83.814988
# Huang High School        81.182722
# Johnson High School      80.966394
# Pena High School         84.044699
# Rodriguez High School    80.744686
# Shelton High School      83.725724
# Thomas High School       83.848930
# Wilson High School       83.989488
# Wright High School       83.955000
# Name: reading_score, dtype: float64

# %%
# Calculate the number of students per school with math scores of 70 or higher
school_students_passing_math = school_data_complete[(school_data_complete['math_score']>=70)]

# school_students_passing_math['school_name'].value_counts()
school_students_passing_math = school_students_passing_math.groupby(["school_name"]).size()
school_students_passing_math.name  = 'passing math'
school_students_passing_math
# Out:
# school_name
# Bailey High School       3318
# Cabrera High School      1749
# Figueroa High School     1946
# Ford High School         1871
# Griffin High School      1371
# Hernandez High School    3094
# Holden High School        395
# Huang High School        1916
# Johnson High School      3145
# Pena High School          910
# Rodriguez High School    2654
# Shelton High School      1653
# Thomas High School       1525
# Wilson High School       2143
# Wright High School       1680
# Name: passing math, dtype: int64

# %%
# Calculate the number of students per school with reading scores of 70 or higher
school_students_passing_reading = school_data_complete[(school_data_complete['reading_score']>=70)]
school_students_passing_reading = school_students_passing_reading.groupby(["school_name"]).size()
school_students_passing_reading.name = 'passing reading'
school_students_passing_reading
# Out:
# school_name
# Bailey High School       4077
# Cabrera High School      1803
# Figueroa High School     2381
# Ford High School         2172
# Griffin High School      1426
# Hernandez High School    3748
# Holden High School        411
# Huang High School        2372
# Johnson High School      3867
# Pena High School          923
# Rodriguez High School    3208
# Shelton High School      1688
# Thomas High School       1591
# Wilson High School       2204
# Wright High School       1739
# Name: passing reading, dtype: int64

# %%
# Use the provided code to calculate the number of students per school that passed both math and reading with scores of 70 or higher
students_passing_math_and_reading = school_data_complete [
                                   (school_data_complete["reading_score"] >= 70) & 
                                   (school_data_complete["math_score"] >= 70)]

# they say to use size which according to a google search:  returns the number of elements (number of rows * the number of columns) in the DataFrame.
school_students_passing_math_and_reading = students_passing_math_and_reading.groupby(["school_name"]).size()
school_students_passing_math_and_reading.name  = 'overall'

school_students_passing_math_and_reading
# Out:
# school_name
# Bailey High School       2719
# Cabrera High School      1697
# Figueroa High School     1569
# Ford High School         1487
# Griffin High School      1330
# Hernandez High School    2481
# Holden High School        381
# Huang High School        1561
# Johnson High School      2549
# Pena High School          871
# Rodriguez High School    2119
# Shelton High School      1583
# Thomas High School       1487
# Wilson High School       2068
# Wright High School       1626
# Name: overall, dtype: int64

# %%
# Use the provided code to calculate the passing rates

# math:
per_school_passing_math = school_students_passing_math/ per_school_counts * 100
per_school_passing_math.name  = 'passing math'

per_school_passing_math
# Out:
# school_name
# Bailey High School       66.680064
# Cabrera High School      94.133477
# Figueroa High School     65.988471
# Ford High School         68.309602
# Griffin High School      93.392371
# Hernandez High School    66.752967
# Holden High School       92.505855
# Huang High School        65.683922
# Johnson High School      66.057551
# Pena High School         94.594595
# Rodriguez High School    66.366592
# Shelton High School      93.867121
# Thomas High School       93.272171
# Wilson High School       93.867718
# Wright High School       93.333333
# Name: passing math, dtype: float64

# %%
# reading
per_school_passing_reading = school_students_passing_reading/ per_school_counts * 100
per_school_passing_reading.name = 'passing reading'

per_school_passing_reading
# Out:
# school_name
# Bailey High School       81.933280
# Cabrera High School      97.039828
# Figueroa High School     80.739234
# Ford High School         79.299014
# Griffin High School      97.138965
# Hernandez High School    80.862999
# Holden High School       96.252927
# Huang High School        81.316421
# Johnson High School      81.222432
# Pena High School         95.945946
# Rodriguez High School    80.220055
# Shelton High School      95.854628
# Thomas High School       97.308869
# Wilson High School       96.539641
# Wright High School       96.611111
# Name: passing reading, dtype: float64

# %%
# overall
overall_passing_rate = school_students_passing_math_and_reading / per_school_counts * 100
overall_passing_rate.name = 'overall passing rate'

overall_passing_rate
# Out:
# school_name
# Bailey High School       54.642283
# Cabrera High School      91.334769
# Figueroa High School     53.204476
# Ford High School         54.289887
# Griffin High School      90.599455
# Hernandez High School    53.527508
# Holden High School       89.227166
# Huang High School        53.513884
# Johnson High School      53.539172
# Pena High School         90.540541
# Rodriguez High School    52.988247
# Shelton High School      89.892107
# Thomas High School       90.948012
# Wilson High School       90.582567
# Wright High School       90.333333
# Name: overall passing rate, dtype: float64

# %%
# Create a DataFrame called `per_school_summary` with columns for the calculations above.
per_school_summary = pd.merge(pd.merge(pd.merge(pd.merge(pd.merge(pd.merge(pd.merge(pd.merge(
                        school_types,per_school_counts, on = 'school_name'), 
                        per_school_budget, on = 'school_name'),
                        per_school_capita, on = 'school_name'),
                        per_school_math, on ='school_name'),
                        per_school_reading, on = 'school_name'),
                        per_school_passing_math, on = 'school_name'),
                        per_school_passing_reading, on = 'school_name'),
                        overall_passing_rate, on = 'school_name')
# reset index !!!!!!
per_school_summary = per_school_summary.reset_index()

# %%
# raw ugly look
per_school_summary
# Out:
#               school_name school typess  total student count     budget  \
# 0       Huang High School      District                 2917  1910635.0
# 1    Figueroa High School      District                 2949  1884411.0
# 2     Shelton High School       Charter                 1761  1056600.0
# 3   Hernandez High School      District                 4635  3022020.0
# 4     Griffin High School       Charter                 1468   917500.0
# 5      Wilson High School       Charter                 2283  1319574.0
# 6     Cabrera High School       Charter                 1858  1081356.0
# 7      Bailey High School      District                 4976  3124928.0
# 8      Holden High School       Charter                  427   248087.0
# 9        Pena High School       Charter                  962   585858.0
# 10     Wright High School       Charter                 1800  1049400.0
# 11  Rodriguez High School      District                 3999  2547363.0
# ...

# %%
# rename the columns
per_school_summary = per_school_summary.rename(columns = {
                        'school_name' : '',
                        'school typess' : 'School Type',
                        'total student count' : 'Total Students',
                        'budget' : 'Total School Budget',
                        'capita' : 'Per Student Budget',
                        'math_score' : 'Average Math Score',
                        'reading_score' : 'Average Reading Score',
                        'passing math' : '% Passing Math',
                        'passing reading' : '% Passing Reading',
                        'overall passing rate' : '% Overall Passing'})
per_school_summary.head(1)
# Out:
#                      School Type  Total Students  Total School Budget  \
# 0  Huang High School    District            2917            1910635.0
#
#    Per Student Budget  Average Math Score  Average Reading Score  \
# 0               655.0           76.629414              81.182722
#
#    % Passing Math  % Passing Reading  % Overall Passing
# 0       65.683922          81.316421          53.513884

# %%
# # Formatting
per_school_summary["Total School Budget"] = per_school_summary["Total School Budget"].map("${:,.2f}".format)
per_school_summary["Per Student Budget"] = per_school_summary["Per Student Budget"].map("${:,.2f}".format)
# per_school_summary['% Passing Math'] = (per_school_summary['% Passing Math']*100).map('{:.2f}%'.format)
# per_school_summary['% Passing Reading'] = (per_school_summary['% Passing Reading']*100).map('{:.2f}%'.format)

# Display the DataFrame
per_school_summary
# Out:
#                           School Type  Total Students Total School Budget  \
# 0       Huang High School    District            2917       $1,910,635.00
# 1    Figueroa High School    District            2949       $1,884,411.00
# 2     Shelton High School     Charter            1761       $1,056,600.00
# 3   Hernandez High School    District            4635       $3,022,020.00
# 4     Griffin High School     Charter            1468         $917,500.00
# 5      Wilson High School     Charter            2283       $1,319,574.00
# 6     Cabrera High School     Charter            1858       $1,081,356.00
# 7      Bailey High School    District            4976       $3,124,928.00
# 8      Holden High School     Charter             427         $248,087.00
# 9        Pena High School     Charter             962         $585,858.00
# 10     Wright High School     Charter            1800       $1,049,400.00
# 11  Rodriguez High School    District            3999       $2,547,363.00
# ...

# %% [markdown]
# ## Highest-Performing Schools (by % Overall Passing)

# %%
# Sort the schools by `% Overall Passing` in descending order and display the top 5 rows.
top_schools = per_school_summary.sort_values('% Overall Passing', ascending = False)

top_schools.head()
# Out:
#                         School Type  Total Students Total School Budget  \
# 6   Cabrera High School     Charter            1858       $1,081,356.00
# 14   Thomas High School     Charter            1635       $1,043,130.00
# 4   Griffin High School     Charter            1468         $917,500.00
# 5    Wilson High School     Charter            2283       $1,319,574.00
# 9      Pena High School     Charter             962         $585,858.00
#
#    Per Student Budget  Average Math Score  Average Reading Score  \
# 6             $582.00           83.061895              83.975780
# 14            $638.00           83.418349              83.848930
# 4             $625.00           83.351499              83.816757
# 5             $578.00           83.274201              83.989488
# 9             $609.00           83.839917              84.044699
#
#     % Passing Math  % Passing Reading  % Overall Passing
# 6        94.133477          97.039828          91.334769
# ...

# %% [markdown]
# ## Bottom Performing Schools (By % Overall Passing)

# %%
# Sort the schools by `% Overall Passing` in ascending order and display the top 5 rows.
bottom_schools = per_school_summary.sort_values('% Overall Passing', ascending = True)

bottom_schools.head()
# Out:
#                           School Type  Total Students Total School Budget  \
# 11  Rodriguez High School    District            3999       $2,547,363.00
# 1    Figueroa High School    District            2949       $1,884,411.00
# 0       Huang High School    District            2917       $1,910,635.00
# 3   Hernandez High School    District            4635       $3,022,020.00
# 12    Johnson High School    District            4761       $3,094,650.00
#
#    Per Student Budget  Average Math Score  Average Reading Score  \
# 11            $637.00           76.842711              80.744686
# 1             $639.00           76.711767              81.158020
# 0             $655.00           76.629414              81.182722
# 3             $652.00           77.289752              80.934412
# 12            $650.00           77.072464              80.966394
#
#     % Passing Math  % Passing Reading  % Overall Passing
# 11       66.366592          80.220055          52.988247
# ...

# %% [markdown]
# ## Math Scores by Grade

# %%
# visualizer
school_data_complete
# Out:
#        Student ID       student_name gender grade         school_name  \
# 0               0       Paul Bradley      M   9th   Huang High School
# 1               1       Victor Smith      M  12th   Huang High School
# 2               2    Kevin Rodriguez      M  12th   Huang High School
# 3               3  Dr. Richard Scott      M  12th   Huang High School
# 4               4         Bonnie Ray      F   9th   Huang High School
# ...           ...                ...    ...   ...                 ...
# 39165       39165       Donna Howard      F  12th  Thomas High School
# 39166       39166          Dawn Bell      F  10th  Thomas High School
# 39167       39167     Rebecca Tanner      F   9th  Thomas High School
# 39168       39168       Desiree Kidd      F  10th  Thomas High School
# 39169       39169    Carolyn Jackson      F  11th  Thomas High School
#
#        reading_score  math_score  School ID      type  size   budget
# ...

# %%
# Use the code provided to separate the data by grade
ninth_graders = school_data_complete[(school_data_complete["grade"] == "9th")]
tenth_graders = school_data_complete[(school_data_complete["grade"] == "10th")]
eleventh_graders = school_data_complete[(school_data_complete["grade"] == "11th")]
twelfth_graders = school_data_complete[(school_data_complete["grade"] == "12th")]


# Group by `school_name` and take the mean of the `math_score` column for each.
ninth_grade_math_scores = ninth_graders.groupby(['school_name'])['math_score'].mean()
tenth_grader_math_scores = tenth_graders.groupby(['school_name'])['math_score'].mean()

eleventh_grader_math_scores = eleventh_graders.groupby(['school_name'])['math_score'].mean()
eleventh_grader_math_scores.name =  "eleven"

twelfth_grader_math_scores = twelfth_graders.groupby (['school_name'])['math_score'].mean()
twelfth_grader_math_scores.name = 'twelve'

# ninth_grade_math_scores 
# Combine each of the scores above into single DataFrame called `math_scores_by_grade`
math_scores_by_grade = pd.merge(pd.merge(pd.merge(
                        ninth_grade_math_scores, tenth_grader_math_scores, on = ['school_name']), 
                        eleventh_grader_math_scores, on = ['school_name']),
                        twelfth_grader_math_scores, on =  ['school_name'])

math_scores_by_grade =  math_scores_by_grade.rename(columns = 
                        {'math_score_x' : '9th',
                        'math_score_y' : '10th', 
                        'eleven' : '11th', 
                        'twelve' : '12th'})

# # # Minor data wrangling
math_scores_by_grade.index.name = None

# # # Display the DataFrame
math_scores_by_grade
# Out:
#                              9th       10th       11th       12th
# Bailey High School     77.083676  76.996772  77.515588  76.492218
# Cabrera High School    83.094697  83.154506  82.765560  83.277487
# Figueroa High School   76.403037  76.539974  76.884344  77.151369
# Ford High School       77.361345  77.672316  76.918058  76.179963
# Griffin High School    82.044010  84.229064  83.842105  83.356164
# Hernandez High School  77.438495  77.337408  77.136029  77.186567
# Holden High School     83.787402  83.429825  85.000000  82.855422
# Huang High School      77.027251  75.908735  76.446602  77.225641
# Johnson High School    77.187857  76.691117  77.491653  76.863248
# Pena High School       83.625455  83.372000  84.328125  84.121547
# Rodriguez High School  76.859966  76.612500  76.395626  77.690748
# Shelton High School    83.420755  82.917411  83.383495  83.778976
# Thomas High School     83.590022  83.087886  83.498795  83.497041
# ...

# %% [markdown]
# ## Reading Score by Grade

# %%
# Use the code provided to separate the data by grade
ninth_graders = school_data_complete[(school_data_complete["grade"] == "9th")]
tenth_graders = school_data_complete[(school_data_complete["grade"] == "10th")]
eleventh_graders = school_data_complete[(school_data_complete["grade"] == "11th")]
twelfth_graders = school_data_complete[(school_data_complete["grade"] == "12th")]

# Group by `school_name` and take the mean of the the `reading_score` column for each.
ninth_grade_reading_scores = ninth_graders.groupby(['school_name'])['reading_score'].mean()
tenth_grader_reading_scores = tenth_graders.groupby(['school_name'])['reading_score'].mean()

eleventh_grader_reading_scores = eleventh_graders.groupby(['school_name'])['reading_score'].mean()
eleventh_grader_reading_scores.name =   "reading 11"

twelfth_grader_reading_scores = twelfth_graders.groupby (['school_name'])['reading_score'].mean()
twelfth_grader_reading_scores.name = "reading 12"

ninth_grade_reading_scores

# Combine each of the scores above into single DataFrame called `reading_scores_by_grade`
reading_scores_by_grade = pd.merge(pd.merge(pd.merge(
                            ninth_grade_reading_scores, tenth_grader_reading_scores, on = ['school_name']), 
                            eleventh_grader_reading_scores, on = ['school_name']),
                            twelfth_grader_reading_scores, on =  ['school_name'])

reading_scores_by_grade =  reading_scores_by_grade.rename(columns = 
                            {'reading_score_x' : '9th', 
                            'reading_score_y' : '10th', 
                            'reading 11' : '11th', 
                            'reading 12' : '12th'})

# Minor data wrangling
reading_scores_by_grade = reading_scores_by_grade[["9th", "10th", "11th", "12th"]]
reading_scores_by_grade.index.name = None

# Display the DataFrame
reading_scores_by_grade
# Out:
#                              9th       10th       11th       12th
# Bailey High School     81.303155  80.907183  80.945643  80.912451
# Cabrera High School    83.676136  84.253219  83.788382  84.287958
# Figueroa High School   81.198598  81.408912  80.640339  81.384863
# Ford High School       80.632653  81.262712  80.403642  80.662338
# Griffin High School    83.369193  83.706897  84.288089  84.013699
# Hernandez High School  80.866860  80.660147  81.396140  80.857143
# Holden High School     83.677165  83.324561  83.815534  84.698795
# Huang High School      81.290284  81.512386  81.417476  80.305983
# Johnson High School    81.260714  80.773431  80.616027  81.227564
# Pena High School       83.807273  83.612000  84.335938  84.591160
# Rodriguez High School  80.993127  80.629808  80.864811  80.376426
# Shelton High School    84.122642  83.441964  84.373786  82.781671
# Thomas High School     83.728850  84.254157  83.585542  83.831361
# ...

# %% [markdown]
# ## Scores by School Spending

# %%
#visualizer
per_school_summary.head()
# Out:
#                          School Type  Total Students Total School Budget  \
# 0      Huang High School    District            2917       $1,910,635.00
# 1   Figueroa High School    District            2949       $1,884,411.00
# 2    Shelton High School     Charter            1761       $1,056,600.00
# 3  Hernandez High School    District            4635       $3,022,020.00
# 4    Griffin High School     Charter            1468         $917,500.00
#
#   Per Student Budget  Average Math Score  Average Reading Score  \
# 0            $655.00           76.629414              81.182722
# 1            $639.00           76.711767              81.158020
# 2            $600.00           83.359455              83.725724
# 3            $652.00           77.289752              80.934412
# 4            $625.00           83.351499              83.816757
#
#    % Passing Math  % Passing Reading  % Overall Passing
# 0       65.683922          81.316421          53.513884
# ...

# %%
# Establish the bins 

spending_bins = [0, 585, 630, 645, 680]
labels = ["<$585", "$585-630", "$630-645", "$645-680"]

# %%
# Create a copy of the school summary since it has the "Per Student Budget" 

school_spending_df = per_school_summary.copy()

# %%
# using per_school_capita bc formatting early on turned some of the rows into strings
school_spending_df['Spending Ranges (Per Student)'] = pd.cut (per_school_capita.values, 
                                                      spending_bins, 
                                                      labels = labels, 
                                                      right = False)

school_spending_df
# Out:
#                           School Type  Total Students Total School Budget  \
# 0       Huang High School    District            2917       $1,910,635.00
# 1    Figueroa High School    District            2949       $1,884,411.00
# 2     Shelton High School     Charter            1761       $1,056,600.00
# 3   Hernandez High School    District            4635       $3,022,020.00
# 4     Griffin High School     Charter            1468         $917,500.00
# 5      Wilson High School     Charter            2283       $1,319,574.00
# 6     Cabrera High School     Charter            1858       $1,081,356.00
# 7      Bailey High School    District            4976       $3,124,928.00
# 8      Holden High School     Charter             427         $248,087.00
# 9        Pena High School     Charter             962         $585,858.00
# 10     Wright High School     Charter            1800       $1,049,400.00
# 11  Rodriguez High School    District            3999       $2,547,363.00
# ...

# %%
school_spending_df.dtypes
# Out:
#                                    object
# School Type                        object
# Total Students                      int64
# Total School Budget                object
# Per Student Budget                 object
# Average Math Score                float64
# Average Reading Score             float64
# % Passing Math                    float64
# % Passing Reading                 float64
# % Overall Passing                 float64
# Spending Ranges (Per Student)    category
# dtype: object

# %%
#  Calculate averages for the desired columns 

spending_math_scores = school_spending_df.groupby(["Spending Ranges (Per Student)"])["Average Math Score"].mean()
spending_reading_scores = school_spending_df.groupby(["Spending Ranges (Per Student)"])["Average Reading Score"].mean()
spending_passing_math = school_spending_df.groupby(["Spending Ranges (Per Student)"])["% Passing Math"].mean()
spending_passing_reading = school_spending_df.groupby(["Spending Ranges (Per Student)"])["% Passing Reading"].mean()
overall_passing_spending = school_spending_df.groupby(["Spending Ranges (Per Student)"])["% Overall Passing"].mean()

# %%
# Assemble into DataFrame
spending_summary = pd.merge(pd.merge(pd.merge(pd.merge(
                    spending_math_scores, spending_reading_scores, on = 'Spending Ranges (Per Student)'), 
                    spending_passing_math, on = 'Spending Ranges (Per Student)'), 
                    spending_passing_reading, on = 'Spending Ranges (Per Student)'),  
                    overall_passing_spending, on = 'Spending Ranges (Per Student)')

# Display results
spending_summary
# Out:
#                                Average Math Score  Average Reading Score  \
# Spending Ranges (Per Student)
# <$585                                   80.073651              82.432247
# $585-630                                80.165885              82.447216
# $630-645                                80.350973              82.395382
# $645-680                                81.375304              82.946146
#
#                                % Passing Math  % Passing Reading  \
# Spending Ranges (Per Student)
# <$585                               80.425930          88.596736
# $585-630                            80.009370          88.655347
# $630-645                            80.002743          88.637793
# $645-680                            84.351212          91.575283
#
#                                % Overall Passing
# Spending Ranges (Per Student)
# <$585                                  72.444286
# $585-630                               71.910532
# ...

# %% [markdown]
# ## Scores by School Size

# %%
per_school_summary.head()
# Out:
#                          School Type  Total Students Total School Budget  \
# 0      Huang High School    District            2917       $1,910,635.00
# 1   Figueroa High School    District            2949       $1,884,411.00
# 2    Shelton High School     Charter            1761       $1,056,600.00
# 3  Hernandez High School    District            4635       $3,022,020.00
# 4    Griffin High School     Charter            1468         $917,500.00
#
#   Per Student Budget  Average Math Score  Average Reading Score  \
# 0            $655.00           76.629414              81.182722
# 1            $639.00           76.711767              81.158020
# 2            $600.00           83.359455              83.725724
# 3            $652.00           77.289752              80.934412
# 4            $625.00           83.351499              83.816757
#
#    % Passing Math  % Passing Reading  % Overall Passing
# 0       65.683922          81.316421          53.513884
# ...

# %%
# Establish the bins.
size_bins = [0, 1000, 2000, 5000]
labels = ["Small (<1000)", "Medium (1000-2000)", "Large (2000-5000)"]

# %%
per_school_summary.dtypes
# Out:
#                           object
# School Type               object
# Total Students             int64
# Total School Budget       object
# Per Student Budget        object
# Average Math Score       float64
# Average Reading Score    float64
# % Passing Math           float64
# % Passing Reading        float64
# % Overall Passing        float64
# dtype: object

# %%
# school_spending_df['Spending Ranges (Per Student)']  = pd.cut (per_school_capita.values, spending_bins, labels = labels, right = False)
# school_spending_df.head()
# Categorize the spending based on the bins
# Use `pd.cut` on the "Total Students" column of the `per_school_summary` DataFrame.

per_school_summary["School Size"] = pd.cut(per_school_summary["Total Students"], 
                                    size_bins, 
                                    labels = labels, 
                                    right = False)
per_school_summary.head()
# Out:
#                          School Type  Total Students Total School Budget  \
# 0      Huang High School    District            2917       $1,910,635.00
# 1   Figueroa High School    District            2949       $1,884,411.00
# 2    Shelton High School     Charter            1761       $1,056,600.00
# 3  Hernandez High School    District            4635       $3,022,020.00
# 4    Griffin High School     Charter            1468         $917,500.00
#
#   Per Student Budget  Average Math Score  Average Reading Score  \
# 0            $655.00           76.629414              81.182722
# 1            $639.00           76.711767              81.158020
# 2            $600.00           83.359455              83.725724
# 3            $652.00           77.289752              80.934412
# 4            $625.00           83.351499              83.816757
#
#    % Passing Math  % Passing Reading  % Overall Passing         School Size
# ...

# %%
# Calculate averages for the desired columns. 
size_math_scores = per_school_summary.groupby(["School Size"])["Average Math Score"].mean()
size_math_scores
# Out:
# School Size
# Small (<1000)         83.821598
# Medium (1000-2000)    83.374684
# Large (2000-5000)     77.746417
# Name: Average Math Score, dtype: float64

# %%
size_reading_scores = per_school_summary.groupby(["School Size"])["Average Reading Score"].mean()
size_reading_scores
# Out:
# School Size
# Small (<1000)         83.929843
# Medium (1000-2000)    83.864438
# Large (2000-5000)     81.344493
# Name: Average Reading Score, dtype: float64

# %%
size_passing_math = per_school_summary.groupby(["School Size"])["% Passing Math"].mean()
size_passing_math
# Out:
# School Size
# Small (<1000)         93.550225
# Medium (1000-2000)    93.599695
# Large (2000-5000)     69.963361
# Name: % Passing Math, dtype: float64

# %%
size_passing_reading = per_school_summary.groupby(["School Size"])["% Passing Reading"].mean()
size_passing_reading
# Out:
# School Size
# Small (<1000)         96.099437
# Medium (1000-2000)    96.790680
# Large (2000-5000)     82.766634
# Name: % Passing Reading, dtype: float64

# %%
size_overall_passing = per_school_summary.groupby(["School Size"])["% Overall Passing"].mean()
size_overall_passing
# Out:
# School Size
# Small (<1000)         89.883853
# Medium (1000-2000)    90.621535
# Large (2000-5000)     58.286003
# Name: % Overall Passing, dtype: float64

# %%
# Create a DataFrame called `size_summary` that breaks down school performance based on school size (small, medium, or large).
# Use the scores above to create a new DataFrame called `size_summary`
size_summary = pd.merge(pd.merge(pd.merge(pd.merge(
                size_math_scores, size_reading_scores, on = 'School Size'),
                size_passing_math, on = 'School Size'),
                size_passing_reading, on = 'School Size'),
                size_overall_passing, on = 'School Size')

# Display results
size_summary
# Out:
#                     Average Math Score  Average Reading Score  % Passing Math  \
# School Size
# Small (<1000)                83.821598              83.929843       93.550225
# Medium (1000-2000)           83.374684              83.864438       93.599695
# Large (2000-5000)            77.746417              81.344493       69.963361
#
#                     % Passing Reading  % Overall Passing
# School Size
# Small (<1000)               96.099437          89.883853
# Medium (1000-2000)          96.790680          90.621535
# Large (2000-5000)           82.766634          58.286003

# %% [markdown]
# ## Scores by School Type

# %%
per_school_summary.head()
# Out:
#                          School Type  Total Students Total School Budget  \
# 0      Huang High School    District            2917       $1,910,635.00
# 1   Figueroa High School    District            2949       $1,884,411.00
# 2    Shelton High School     Charter            1761       $1,056,600.00
# 3  Hernandez High School    District            4635       $3,022,020.00
# 4    Griffin High School     Charter            1468         $917,500.00
#
#   Per Student Budget  Average Math Score  Average Reading Score  \
# 0            $655.00           76.629414              81.182722
# 1            $639.00           76.711767              81.158020
# 2            $600.00           83.359455              83.725724
# 3            $652.00           77.289752              80.934412
# 4            $625.00           83.351499              83.816757
#
#    % Passing Math  % Passing Reading  % Overall Passing         School Size
# ...

# %%
# Group the per_school_summary DataFrame by "School Type" and average the results.
average_math_score_by_type = per_school_summary.groupby(["School Type"])["Average Math Score"].mean()
average_math_score_by_type
# Out:
# School Type
# Charter     83.473852
# District    76.956733
# Name: Average Math Score, dtype: float64

# %%
average_reading_score_by_type = per_school_summary.groupby(["School Type"])["Average Reading Score"].mean()
average_reading_score_by_type
# Out:
# School Type
# Charter     83.896421
# District    80.966636
# Name: Average Reading Score, dtype: float64

# %%
average_percent_passing_math_by_type = per_school_summary.groupby(["School Type"])["% Passing Math"].mean()
average_percent_passing_math_by_type
# Out:
# School Type
# Charter     93.620830
# District    66.548453
# Name: % Passing Math, dtype: float64

# %%
average_percent_passing_reading_by_type = per_school_summary.groupby(["School Type"])["% Passing Reading"].mean()
average_percent_passing_reading_by_type
# Out:
# School Type
# Charter     96.586489
# District    80.799062
# Name: % Passing Reading, dtype: float64

# %%
average_percent_overall_passing_by_type = per_school_summary.groupby(["School Type"])["% Overall Passing"].mean()
average_percent_overall_passing_by_type
# Out:
# School Type
# Charter     90.432244
# District    53.672208
# Name: % Overall Passing, dtype: float64

# %%
# Assemble the new data by type into a DataFrame called `type_summary`
type_summary = pd.merge(pd.merge(pd.merge(pd.merge(
                average_math_score_by_type, average_reading_score_by_type, on = 'School Type'),
                average_percent_passing_math_by_type, on = 'School Type'),
                average_percent_passing_reading_by_type, on = 'School Type'),
                average_percent_overall_passing_by_type, on = 'School Type')

# Display results
type_summary
# Out:
#              Average Math Score  Average Reading Score  % Passing Math  \
# School Type
# Charter               83.473852              83.896421       93.620830
# District              76.956733              80.966636       66.548453
#
#              % Passing Reading  % Overall Passing
# School Type
# Charter              96.586489          90.432244
# District             80.799062          53.672208
